# %%
valid_solutions = {0: 1, 1: 0, 2: 3, 3: 2}
valid_solutions
# Out:
# {0: 1, 1: 0, 2: 3, 3: 2}

# %%
unvisited = list(range(4))
shortest_cycle = list(range(4))

while unvisited:
    current_cycle = []
    node = unvisited[0]

    while node in unvisited:
        unvisited.remove(node)
        current_cycle.append(node)
        node = valid_solutions[node]
        print(node)
        print("Unvisited: ", unvisited)
    
    print(current_cycle)
    if len(current_cycle) < len(shortest_cycle):
        shortest_cycle = current_cycle
# Out:
# 1
# Unvisited:  [1, 2, 3]
# 0
# Unvisited:  [2, 3]
# [0, 1]
# 3
# Unvisited:  [3]
# 2
# Unvisited:  []
# [2, 3]
